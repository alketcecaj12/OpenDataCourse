# %%
import pandas as pd

# %%
data = pd.read_csv("Italy/EmiliaRomagnaTraffic/MTSReport/RilevazioniPerCorsia.csv", sep = ";")

# %%
data
# Out:
#     AnnoMese  Postazione      Giorno  N Giorno Settimana  \
# 0    2025/01         177  18/01/2025                   6
# 1    2025/01         177  18/01/2025                   6
# 2    2025/01         177  19/01/2025                   7
# 3    2025/01         177  19/01/2025                   7
# 4    2025/01         177  20/01/2025                   1
# ..       ...         ...         ...                 ...
# 135  2025/01         665  29/01/2025                   3
# 136  2025/01         665  30/01/2025                   4
# 137  2025/01         665  30/01/2025                   4
# 138  2025/01         665  31/01/2025                   5
# 139  2025/01         665  31/01/2025                   5
#
#                                                 Strada  \
# 0    NSA 313 complanare sud alla A 14 nel tratto tr...
# 1    NSA 313 complanare sud alla A 14 nel tratto tr...
# 2    NSA 313 complanare sud alla A 14 nel tratto tr...
# ...
