# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dati = pd.read_csv("MTSReport /RilevazioniPerPostazione.csv", sep = ";", thousands='.')

# %%
dati.head()
# Out:
#   AnnoMese  Postazione      Giorno  N Giorno Settimana  \
# 0  2025/01           6  25/01/2025                   6
# 1  2025/01           6  27/01/2025                   1
# 2  2025/01           7  18/01/2025                   6
# 3  2025/01           7  19/01/2025                   7
# 4  2025/01           7  20/01/2025                   1
#
#                                               Strada  Transiti - Totale  \
# 0     SS 12 tra Fiumalbo e confine regionale Toscana             1736.0
# 1     SS 12 tra Fiumalbo e confine regionale Toscana              942.0
# 2  SS 64 a Ponte della Venturina (Porretta Terme)...                NaN
# 3  SS 64 a Ponte della Venturina (Porretta Terme)...                NaN
# 4  SS 64 a Ponte della Venturina (Porretta Terme)...                NaN
#
#    Transiti - Non Classificato  Transiti - Leggeri  Transiti - Pesanti  \
# 0                          0.0              1726.0                10.0
# ...

# %%
dati = dati.convert_dtypes()

# %%
dati.shape
# Out:
# (2932, 13)

# %%
gbs = dati.groupby("Strada")

# %%
for s, df in gbs: 
    print(s, len(df))
# Out:
# NSA 313 complanare sud alla A 14 nel tratto tra San Lazzaro e Idice 14
# Piazzale Milano sul ponte fiume Po al confine regionale Lombardia 14
# SP 1 (tangenziale sud/ovest di Piacenza) tra Madonna del Pilastro (SP 7) e Piacenza 14
# SP 1 a Villafranca di Forli' al confine provinciale Forli'-Cesena/Ravenna 14
# SP 1 tra Crevalcore e San Matteo della Decima 14
# SP 10 tra Parma (viadotto A 1) e Viarolo 14
# SP 10 tra Polesine Parmense e Ragazzola (ponte fiume Po) 14
# SP 10 tra San Matteo della Decima e Bevilacqua (confine provinciale Bologna/Ferrara) 14
# SP 10 tra San Mauro Pascoli e San Mauro Mare 14
# SP 10 tra San Secondo Parmense e Ragazzola (ponte fiume Po) 14
# SP 10(1) a Ragazzola sul ponte del fiume Po (confine regionale Lombardia) 14
# SP 11 a Roncole Verdi tra Busseto e Soragna 14
# SP 11 tra Borgonovo Val Tidone e Mottaziana (ponte torrente Tidone) 14
# SP 11 tra Fontevivo e tangenziale di Parma 14
# SP 11 tra Pieve di Cento e San Pietro in Casale 14
# ...

# %%
s5 = gbs.get_group("SP 5 tra Reggiolo e Novellara")
s5
# Out:
#      AnnoMese  Postazione      Giorno  N Giorno Settimana  \
# 2124  2025/01         448  18/01/2025                   6
# 2125  2025/01         448  19/01/2025                   7
# 2126  2025/01         448  20/01/2025                   1
# 2127  2025/01         448  21/01/2025                   2
# 2128  2025/01         448  22/01/2025                   3
# 2129  2025/01         448  23/01/2025                   4
# 2130  2025/01         448  24/01/2025                   5
# 2131  2025/01         448  25/01/2025                   6
# 2132  2025/01         448  26/01/2025                   7
# 2133  2025/01         448  27/01/2025                   1
# 2134  2025/01         448  28/01/2025                   2
# 2135  2025/01         448  29/01/2025                   3
# 2136  2025/01         448  30/01/2025                   4
# 2137  2025/01         448  31/01/2025                   5
#
#                              Strada  Transiti - Totale  \
# ...

# %%
s5.shape
# Out:
# (14, 13)

# %%
s = s5.iloc[:, 2:6]
s
# Out:
#           Giorno  N Giorno Settimana                         Strada  \
# 2124  18/01/2025                   6  SP 5 tra Reggiolo e Novellara
# 2125  19/01/2025                   7  SP 5 tra Reggiolo e Novellara
# 2126  20/01/2025                   1  SP 5 tra Reggiolo e Novellara
# 2127  21/01/2025                   2  SP 5 tra Reggiolo e Novellara
# 2128  22/01/2025                   3  SP 5 tra Reggiolo e Novellara
# 2129  23/01/2025                   4  SP 5 tra Reggiolo e Novellara
# 2130  24/01/2025                   5  SP 5 tra Reggiolo e Novellara
# 2131  25/01/2025                   6  SP 5 tra Reggiolo e Novellara
# 2132  26/01/2025                   7  SP 5 tra Reggiolo e Novellara
# 2133  27/01/2025                   1  SP 5 tra Reggiolo e Novellara
# 2134  28/01/2025                   2  SP 5 tra Reggiolo e Novellara
# 2135  29/01/2025                   3  SP 5 tra Reggiolo e Novellara
# 2136  30/01/2025                   4  SP 5 tra Reggiolo e Novellara
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 2124 to 2137
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Giorno              14 non-null     string
#  1   N Giorno Settimana  14 non-null     Int64
#  2   Strada              14 non-null     string
#  3   Transiti - Totale   14 non-null     Int64
# dtypes: Int64(2), string(2)
# memory usage: 588.0 bytes

# %%
s2 = s5[["Giorno", "Transiti - Totale"]]
s2["Giorno"] = pd.to_datetime(s2["Giorno"])
# Out:
# /var/folders/tt/zbxpsbdn7fd6_zbyqkfm28d40000gn/T/ipykernel_4308/4109839071.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   s2["Giorno"] = pd.to_datetime(s2["Giorno"])
# /var/folders/tt/zbxpsbdn7fd6_zbyqkfm28d40000gn/T/ipykernel_4308/4109839071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s2["Giorno"] = pd.to_datetime(s2["Giorno"])

# %%
s2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 2124 to 2137
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Giorno             14 non-null     datetime64[ns]
#  1   Transiti - Totale  14 non-null     Int64
# dtypes: Int64(1), datetime64[ns](1)
# memory usage: 350.0 bytes

# %%
s2 = s2.set_index("Giorno")
s2
# Out:
#             Transiti - Totale
# Giorno
# 2025-01-18               5845
# 2025-01-19               4518
# 2025-01-20               7105
# 2025-01-21               7311
# 2025-01-22               7359
# 2025-01-23               7281
# 2025-01-24               7488
# 2025-01-25               5832
# 2025-01-26               4807
# 2025-01-27               7093
# 2025-01-28               7381
# 2025-01-29               7457
# 2025-01-30               7502
# 2025-01-31               7432

# %%
s2 = s2.fillna(0)

# %%
s2["Transiti - Totale"] = s2["Transiti - Totale"].astype(int)
s2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14 entries, 2025-01-18 to 2025-01-31
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transiti - Totale  14 non-null     int64
# dtypes: int64(1)
# memory usage: 224.0 bytes

# %%
plt.figure(figsize = (20, 5))
plt.plot(s2)
plt.show()
