# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Export_RE_2025-03-26.csv")

# %%
data.head()
# Out:
#                data  CASTELLARANO v_CASTELLARANO  FEBBIO v_FEBBIO  S. LAZZARO  \
# 0  2024-01-01 00:00          19.0              S     4.0        S        27.0
# 1  2024-01-02 00:00          21.0              S    10.0        S        19.0
# 2  2024-01-03 00:00          27.0              S     7.0        S        30.0
# 3  2024-01-04 00:00          25.0              S    10.0        S        37.0
# 4  2024-01-05 00:00          38.0              S     2.0        S        43.0
#
#   v_S. LAZZARO  S. ROCCO v_S. ROCCO  TIMAVO v_TIMAVO
# 0            S      31.0          S    26.0        S
# 1            S      20.0          S    18.0        S
# 2            S      31.0          S    34.0        S
# 3            S      34.0          S    43.0        S
# 4            S      27.0          S    38.0        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            449 non-null    object
#  1   CASTELLARANO    443 non-null    float64
#  2   v_CASTELLARANO  443 non-null    object
#  3   FEBBIO          442 non-null    float64
#  4   v_FEBBIO        442 non-null    object
#  5   S. LAZZARO      440 non-null    float64
#  6   v_S. LAZZARO    440 non-null    object
#  7   S. ROCCO        444 non-null    float64
#  8   v_S. ROCCO      444 non-null    object
#  9   TIMAVO          444 non-null    float64
#  10  v_TIMAVO        444 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 38.7+ KB

# %%
data.describe()
# Out:
#        CASTELLARANO      FEBBIO  S. LAZZARO    S. ROCCO      TIMAVO
# count    443.000000  442.000000  440.000000  444.000000  444.000000
# mean      24.968397   10.180995   25.631818   27.351351   32.263514
# std       15.124039   11.634213   15.677731   16.688975   17.959961
# min        5.000000    0.000000    4.000000    2.000000    4.000000
# 25%       15.000000    5.000000   15.000000   16.000000   19.000000
# 50%       21.000000    8.000000   21.000000   24.000000   28.500000
# 75%       31.000000   13.000000   32.000000   35.000000   42.000000
# max      102.000000  171.000000   93.000000  120.000000  123.000000

# %% [markdown]
# ### Funzioni di pandas per prendere porzioni diverse di dataframe
#
# - indice iloc per tagliare i data frame in righe e colonne
# - filtraggio righe con le espressioni booleane
# -

# %%
data
# Out:
#                  data  CASTELLARANO v_CASTELLARANO  FEBBIO v_FEBBIO  \
# 0    2024-01-01 00:00          19.0              S     4.0        S
# 1    2024-01-02 00:00          21.0              S    10.0        S
# 2    2024-01-03 00:00          27.0              S     7.0        S
# 3    2024-01-04 00:00          25.0              S    10.0        S
# 4    2024-01-05 00:00          38.0              S     2.0        S
# ..                ...           ...            ...     ...      ...
# 444  2025-03-20 00:00          27.0              G    12.0        G
# 445  2025-03-21 00:00          39.0              G    21.0        G
# 446  2025-03-22 00:00          20.0              G     4.0        G
# 447  2025-03-23 00:00          14.0              G     8.0        G
# 448  2025-03-24 00:00          12.0              G     9.0        G
#
#      S. LAZZARO v_S. LAZZARO  S. ROCCO v_S. ROCCO  TIMAVO v_TIMAVO
# 0          27.0            S      31.0          S    26.0        S
# ...

# %%
p1 = data.iloc[0:3, 0:3]

# %%
p1
# Out:
#                data  CASTELLARANO v_CASTELLARANO
# 0  2024-01-01 00:00          19.0              S
# 1  2024-01-02 00:00          21.0              S
# 2  2024-01-03 00:00          27.0              S

# %%
m50 = data[data['CASTELLARANO'] > 50]

# %%
m50.head()
# Out:
#                 data  CASTELLARANO v_CASTELLARANO  FEBBIO v_FEBBIO  \
# 14  2024-01-15 00:00          61.0              S     0.0        S
# 15  2024-01-16 00:00          59.0              S     6.0        S
# 16  2024-01-17 00:00          61.0              S     0.0        S
# 24  2024-01-25 00:00          58.0              S     NaN      NaN
# 25  2024-01-26 00:00          74.0              S    11.0        S
#
#     S. LAZZARO v_S. LAZZARO  S. ROCCO v_S. ROCCO  TIMAVO v_TIMAVO
# 14        58.0            S      62.0          S    58.0        S
# 15        56.0            S      45.0          S    53.0        S
# 16        51.0            S      43.0          S    46.0        S
# 24        71.0            S      68.0          S    73.0        S
# 25        72.0            S      41.0          S    73.0        S

# %%
vS = data[data['v_CASTELLARANO'] == 'S']

# %% [markdown]
# ### Prima visualizzazione dati in ottica descrittiva.
#
# - descriptive statistics
#
# - istogramma
#
# - grafico a barre
#
# - boxplot
#
# - trattamento dati mancanti

# %%
c = data["CASTELLARANO"]

# %%
plt.figure(figsize = (5, 5))
plt.hist(c, bins=30)
plt.show()

# %%
data.describe()
# Out:
#        CASTELLARANO      FEBBIO  S. LAZZARO    S. ROCCO      TIMAVO
# count    443.000000  442.000000  440.000000  444.000000  444.000000
# mean      24.968397   10.180995   25.631818   27.351351   32.263514
# std       15.124039   11.634213   15.677731   16.688975   17.959961
# min        5.000000    0.000000    4.000000    2.000000    4.000000
# 25%       15.000000    5.000000   15.000000   16.000000   19.000000
# 50%       21.000000    8.000000   21.000000   24.000000   28.500000
# 75%       31.000000   13.000000   32.000000   35.000000   42.000000
# max      102.000000  171.000000   93.000000  120.000000  123.000000

# %%
medie = [25, 10, 25, 27, 32]
stz = ["CASTELLARANO", "FEBBIO", "S. LAZZARO", "S. ROCCO", "TIMAVO"]

# %%
plt.bar(stz, medie)
plt.show()

# %%
data = data.fillna(0)

# %%
plt.figure(figsize = (20, 3))
t = data["FEBBIO"]
plt.boxplot(t, vert=False)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            449 non-null    object
#  1   CASTELLARANO    443 non-null    float64
#  2   v_CASTELLARANO  443 non-null    object
#  3   FEBBIO          442 non-null    float64
#  4   v_FEBBIO        442 non-null    object
#  5   S. LAZZARO      440 non-null    float64
#  6   v_S. LAZZARO    440 non-null    object
#  7   S. ROCCO        444 non-null    float64
#  8   v_S. ROCCO      444 non-null    object
#  9   TIMAVO          444 non-null    float64
#  10  v_TIMAVO        444 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 38.7+ KB
